# %%
from embeddings import (
    plot_embeddings,
    compute_marker_parameter_correlations,
    plot_binned_dynamic_cytof,
    get_available_parameters,
    plot_embeddings_all_parameters,
    sensitive_pars,
    plot_marker_parameter_volcano_grid,
    plot_marker_parameter_barplots,
)

# %%
# Get available parameters for a model
params = get_available_parameters("EGFR_MAPK__logobs_tegfr_aggavg", "figure3")
print(f"Available parameters ({len(params)}):")
print(params[:20])
# Out:
# Available parameters (44):
# ['ERBB3_dp_Y1289_kcat', 'ERBB2_dp_Y1248_kcat', 'EGFR_deg_kdeg', 'EGFR_dp_Y1173_kcat', 'EGFR_recycle_kcat', 'MEK_dp_S222_kcat', 'TOPK_dp_Y74_kcat', 'ERK_dp_Y204_kcat', 'RPS6KA1_dp_S380_kcat', 'ERBB3_p_Y1289_bact', 'ERBB3_p_Y1289_serum_0_kw', 'ERBB2_p_Y1248_bact', 'ERBB2_p_Y1248_ERBB2_kw', 'ERBB2_p_Y1248_EGFR__Y1173_p_kw', 'ERBB2_p_Y1248_ERBB3__Y1289_p_kw', 'ERBB2_p_Y1248_serum_0_kw', 'ERBB2_p_Y1248_iEGFR_0_kw', 'EGFR_p_Y1173_bact', 'EGFR_p_Y1173_EGF_0_kw', 'EGFR_p_Y1173_serum_0_kw']

# %%
# Plot embeddings colored by EGFR parameter
plot_embeddings(
    model="EGFR_MAPK__logobs_tegfr_aggavg",
    context="cytof_init",
    color_by="EGFR_p_Y1173_EGF_0_kw",
    marker_data_type="parameter",
    figure="figure3",
);

# %%
plot_embeddings_all_parameters(
    model="EGFR_MAPK__logobs_tegfr_aggavg",
    context="cytof_init",
    figure="figure3",
    n_cols=3,
    parameters=sensitive_pars,
    x_col="L1",
    y_col="L2",
);

# %%
for dir in ["D1", "D2", "D3"]:
    # Plot dynamic cytof data binned by parameter
    plot_binned_dynamic_cytof(
        model="EGFR_MAPK__logobs_tegfr_aggavg",
        context="cytof_init",
        observables=["p.HER2", "p.MEK", "p.ERK", "p.p90RSK"],
        conditions=["EGF", "iMEK", "iEGFR"],
        bin_by=dir,
        bin_by_type="parameter",
        figure="figure3",
    );
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 3
#       1 for dir in ["D1", "D2", "D3"]:
#       2     # Plot dynamic cytof data binned by parameter
# ----> 3     plot_binned_dynamic_cytof(
#       4         model="EGFR_MAPK__logobs_tegfr_aggavg",
#       5         context="cytof_init",
#       6         observables=["p.HER2", "p.MEK", "p.ERK", "p.p90RSK"],
#       7         conditions=["EGF", "iMEK", "iEGFR"],
#       8         bin_by=dir,
#       9         bin_by_type="parameter",
#      10         figure="figure3",
#      11     );
#
# File ~/Documents/projects/DeepMechanisticModels/figures_paper/embeddings.py:2079, in plot_binned_dynamic_cytof(model, context, observables, conditions, bin_by, bin_by_type, n_bins, bin_labels, figure, data, figsize, cmap, save_path)
#    2076     bin_values = emb_df[bin_by]
#    2077 elif bin_by_type == "parameter":
#    2078     # Load parameter data for binning
# -> 2079     param_values = load_parameter_data(
#    2080         model, bin_by, figure, data, context
#    2081     )
#    2082     bin_values = emb_df.index.map(param_values)
#    2083 elif bin_by_type == "parameter_group":
#    2084     # Bin by parameter group: compute averaged gradients in embedding space
#
# File ~/Documents/projects/DeepMechanisticModels/figures_paper/embeddings.py:221, in load_parameter_data(model, parameter, figure, data, context)
#     219 available_params = get_available_parameters(model, figure, data)
#     220 if parameter not in available_params:
# --> 221     raise ValueError(
#     222         f"Parameter '{parameter}' not found. Available parameters: {available_params[:10]}..."
#     223     )
#     225 filepath = evaluations_dir / model / data / f"param_devs_{figure}.csv"
#     226 df = pd.read_csv(filepath, index_col=0)
#
# ValueError: Parameter 'D1' not found. Available parameters: ['ERBB3_dp_Y1289_kcat', 'ERBB2_dp_Y1248_kcat', 'EGFR_deg_kdeg', 'EGFR_dp_Y1173_kcat', 'EGFR_recycle_kcat', 'MEK_dp_S222_kcat', 'TOPK_dp_Y74_kcat', 'ERK_dp_Y204_kcat', 'RPS6KA1_dp_S380_kcat', 'ERBB3_p_Y1289_bact']...

# %%
groups = ["D1", "D2", "D3"]

# %%
for method in ["pearson", "spearman", "differential_expression"]:
    de_df = compute_marker_parameter_correlations(
        model="EGFR_MAPK__logobs_tegfr_aggavg",
        context="cytof_init",
        parameters=["D1", "D2", "D3"],
        data_type="cytof",
        method=method,
        figure="figure3",
    )
    plot_marker_parameter_volcano_grid(de_df, method=method)

# %%
for method in ["pearson", "spearman", "differential_expression"]:
    de_df = compute_marker_parameter_correlations(
        model="EGFR_MAPK__logobs_tegfr_aggavg",
        context="cytof_init",
        parameters=["D1", "D2", "D3"],
        data_type="transcriptomics",
        method=method,
        figure="figure3",
    )
    plot_marker_parameter_volcano_grid(de_df, method=method)

# %%
for datatype in ["transcriptomics", "proteomics", "cytof"]:
    # With correlation output
    corr_df = compute_marker_parameter_correlations(
        model="EGFR_MAPK__logobs_tegfr_aggavg",
        context="cytof_init",
        parameters=["D1", "D2", "D3"],
        data_type=datatype,
        method="spearman",
        figure="figure3",
    )
    plot_marker_parameter_barplots(
        corr_df,
        parameters=["D1", "D2", "D3"],
        n_top=10,
        title=f"{datatype.capitalize()} markers",
        save_path=f"correlation_barplots_{datatype}.pdf",
    )
