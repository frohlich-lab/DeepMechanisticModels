# %%
from embeddings import (
    plot_embeddings,
    sensitive_pars,
)

# %%
plot_embeddings(
    model="EGFR_MAPK__logobs_tegfr_aggavg",
    context="cytof_init",
    color_by="p.p90RSK",
    marker_data_type="cytof",
);

# %%
plot_embeddings(
    model="EGFR_MAPK__logobs_tegfr_aggavg",
    context="cytof_init",
    color_by="p.HER2",
    marker_data_type="cytof",
);

# %%
plot_embeddings(
    model="EGFR_MAPK__logobs_tegfr_aggavg",
    context="cytof_init",
    color_by="p.MEK",
    marker_data_type="cytof",
    x_col="L3",
);

# %%
plot_embeddings(
    model="EGFR_MAPK__logobs_tegfr_aggavg",
    context="cytof_init",
    color_by="p.p90RSK",
    marker_data_type="cytof",
);

# %%
# Example: Plot colored by EGFR transcriptomics
plot_embeddings(
    model="EGFR_MAPK__logobs",
    context="cytof_init",
    color_by="MAP3K8",
    marker_data_type="transcriptomics",
);

# %%
plot_embeddings(
    figure="figure1a",
    model="EGFR_MAPK__logobs",
    context="multimodal",
    color_by="luminalbasal"
);

# %%
plot_embeddings(
    figure="figure1a",
    model="EGFR_MAPK__logobs",
    context="multimodal",
    color_by="EGFR",
    marker_data_type="transcriptomics",
);

# %%
plot_embeddings(
    figure="figure1a",
    model="EGFR_MAPK__logobs",
    context="multimodal",
    color_by="MAP3K8",
    marker_data_type="transcriptomics",
);
